# %% [markdown]
# ### LSE Data Analytics Online Career Accelerator
#
# # DA201: Data Analytics using Python

# %% [markdown]
# ## Practical activity: Search the Twitter API

# %% [markdown]
# **Scenario**
#
# The story of Bitcoin and other cryptocurrencies has captured investors like few financial stories have. Many finance firms are looking to invest in the crypto market. As a data analyst at a financial institution, your manager has tasked you with investigating Bitcoin in a little more detail, particularly in terms of future growth of the currency and its use in the United States.
#
# Earlier, as a data analyst at a financial institution, your manager tasked you with investigating Bitcoin in terms of future growth and its use in the United States. Previously, you accessed Bitcoin data through the Coingecko API. Now, your manager asks you to turn your attention to Twitter, particularly tweets on Bitcoin and cryptocurrency in general. Your manager particularly wants you to check if Bitcoin is trending in `New York, Los Angeles, Sydney, Auckland, and Dubai`.
#
# She also wants to see a DataFrame of topics with over `200,000` tweets for each city.
#
# Your manager then wants you to cross-check trending topics between the `United States and the UK`, to see what people are talking about in both countries, and if Bitcoin forms part of the larger conversation. If Bitcoin is not a shared trending topic, then she asks that you search Twitter for `#Bitcoin` and two other cryptocurrency hashtags of your choice, and analyse the top two tweets you return for each hashtag, particularly in terms of their popularity.

# %% [markdown]
# ## 1. Prepare your workstation

# %%
# Copy the YAML file and your Twitter keys over before you start to work.
import yaml
from yaml.loader import SafeLoader
from twitter import *

# Import the YAML file – remember to specify the whole path.
twitter_creds = yaml.safe_load(open('twitter.yaml', 'r').read())

# Pass your Twitter credentials.
twitter_api = Twitter(auth=OAuth(twitter_creds['access_token'],
                                 twitter_creds['access_token_secret'], 
                                 twitter_creds['api_key'],
                                 twitter_creds['api_secret_key'] ))

# %%
# See if you are connected.
print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x000001E39146DF70>

# %%
# Run a test with #python.
python_tweets = twitter_api.search.tweets(q='#python')

# View the output.
print(python_tweets)
# Out:
# {'statuses': [{'created_at': 'Thu Feb 09 11:27:59 +0000 2023', 'id': 1623644878461628416, 'id_str': '1623644878461628416', 'text': 'RT @xen0f0n: https://t.co/5iZgScXLqr\n\n#earthobservation #remotesensing #machinelearning #deeplearning #python @robmarkcole @planet @samapri…', 'truncated': False, 'entities': {'hashtags': [{'text': 'earthobservation', 'indices': [38, 55]}, {'text': 'remotesensing', 'indices': [56, 70]}, {'text': 'machinelearning', 'indices': [71, 87]}, {'text': 'deeplearning', 'indices': [88, 101]}, {'text': 'python', 'indices': [102, 109]}], 'symbols': [], 'user_mentions': [{'screen_name': 'xen0f0n', 'name': 'Akis Karagiannis', 'id': 1032587510, 'id_str': '1032587510', 'indices': [3, 11]}, {'screen_name': 'robmarkcole', 'name': 'Robin Cole', 'id': 30924981, 'id_str': '30924981', 'indices': [110, 122]}, {'screen_name': 'planet', 'name': 'Planet', 'id': 17663776, 'id_str': '17663776', 'indices': [123, 130]}], 'urls': [{'url': 'https://t.co/5iZgScXLqr', 'expanded_url': 'https://medium.com/spectral-reflectance/spectral-reflectance-newsletter-20-1d571c782aaa', 'display_url': 'medium.com/spectral-refle…', 'indices': [13, 36]}]}, 'metadata': {'iso_language_code': 'und', 'result_type': 'recent'}, 'source': '<a href="http://twinybots.com" rel="nofollow">TwinyBots</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 996318990715838465, 'id_str': '996318990715838465', 'name': 'Digital Together', 'screen_name': 'DigiTogether', 'location': 'Brussels, Belgium', 'description': 'The official account of Digital Together. We advocate for and represent the voice of digitally-active citizens #DigitalHelpsUsLiveBetter is our motto 📱💻🎙️', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1388, 'friends_count': 1055, 'listed_count': 34, 'created_at': 'Tue May 15 09:18:52 +0000 2018', 'favourites_count': 8972, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 40961, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1009625260008718336/9dsSgvwL_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1009625260008718336/9dsSgvwL_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/996318990715838465/1531128174', 'profile_link_color': 'F3AC31', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Thu Feb 09 09:28:51 +0000 2023', 'id': 1623614896612016130, 'id_str': '1623614896612016130', 'text': 'https://t.co/5iZgScXLqr\n\n#earthobservation #remotesensing #machinelearning #deeplearning #python @robmarkcole @planet @samapriyaroy', 'truncated': False, 'entities': {'hashtags': [{'text': 'earthobservation', 'indices': [25, 42]}, {'text': 'remotesensing', 'indices': [43, 57]}, {'text': 'machinelearning', 'indices': [58, 74]}, {'text': 'deeplearning', 'indices': [75, 88]}, {'text': 'python', 'indices': [89, 96]}], 'symbols': [], 'user_mentions': [{'screen_name': 'robmarkcole', 'name': 'Robin Cole', 'id': 30924981, 'id_str': '30924981', 'indices': [97, 109]}, {'screen_name': 'planet', 'name': 'Planet', 'id': 17663776 ...

# %% [markdown]
# ## 2. Identify worldwide trends

# %%
# Identify worldwide trends
trends_worldwide = twitter_api.trends.available()

# Identify the number of available trends
print(len(trends_worldwide))

# Example of trends_worldwide
trends_worldwide[0]
# Out:
# 467
# {'name': 'Worldwide',
#  'placeType': {'code': 19, 'name': 'Supername'},
#  'url': 'http://where.yahooapis.com/v1/place/1',
#  'parentid': 0,
#  'country': '',
#  'woeid': 1,
#  'countryCode': None}

# %% [markdown]
# ## London

# %%
# Identify specific city (London)

our_city = 'London'

# Create a variable.
list_of_names_our_city = [_ for _ in trends_worldwide if _['name'] == our_city]

# View the output.
print(len(list_of_names_our_city))

# Use index to find London.
list_of_names_our_city[0]
# Out:
# 1
# {'name': 'London',
#  'placeType': {'code': 7, 'name': 'Town'},
#  'url': 'http://where.yahooapis.com/v1/place/44418',
#  'parentid': 23424975,
#  'country': 'United Kingdom',
#  'woeid': 44418,
#  'countryCode': 'GB'}

# %%
# List of 'where on earth identifiers' (woeid)
list_of_names_our_city[0]['woeid']
# Out:
# 44418

# %%
london_trends = twitter_api.trends.place(_id = list_of_names_our_city[0]['woeid'])

# View the output
london_trends
# Out:
# [{'trends': [{'name': '#NAW2023',
#     'url': 'http://twitter.com/search?q=%23NAW2023',
#     'promoted_content': None,
#     'query': '%23NAW2023',
#     'tweet_volume': None},
#    {'name': '#ThisMorning',
#     'url': 'http://twitter.com/search?q=%23ThisMorning',
#     'promoted_content': None,
#     'query': '%23ThisMorning',
#     'tweet_volume': None},
#    {'name': 'Durant',
#     'url': 'http://twitter.com/search?q=Durant',
#     'promoted_content': None,
#     'query': 'Durant',
#     'tweet_volume': 144569},
#    {'name': 'Elon',
#     'url': 'http://twitter.com/search?q=Elon',
#     'promoted_content': None,
#     'query': 'Elon',
#     'tweet_volume': 351642},
#    {'name': '#skillsforlife',
#     'url': 'http://twitter.com/search?q=%23skillsforlife',
#     'promoted_content': None,
#     'query': '%23skillsforlife',
#     'tweet_volume': None},
#    {'name': '#apprenticeships',
#     'url': 'http://twitter.com/search?q=%23apprenticeships',
#     'promoted_content': None,
#     'query': '%23apprenticeships',
#     'tweet_volume': None},
#    {'name': 'Russ',
#     'url': 'http://twitter.com/search?q=Russ',
#     'promoted_content': None,
#     'query': 'Russ',
#     'tweet_volume': 66798},
#    {'name': 'Churchill',
#     'url': 'http://twitter.com/search?q=Churchill',
#     'promoted_content': None,
#     'query': 'Churchill',
#     'tweet_volume': 11997},
#    {'name': 'Lee Anderson',
#     'url': 'http://twitter.com/search?q=%22Lee+Anderson%22',
#     'promoted_content': None,
#     'query': '%22Lee+Anderson%22',
#     'tweet_volume': 38344},
#    {'name': 'European Super League',
#     'url': 'http://twitter.com/search?q=%22European+Super+League%22',
#     'promoted_content': None,
#     'query': '%22European+Super+League%22',
#     'tweet_volume': None},
#    {'name': 'Brian Hughes',
#     'url': 'http://twitter.com/search?q=%22Brian+Hughes%22',
#     'promoted_content': None,
#     'query': '%22Brian+Hughes%22',
#     'tweet_volume': None},
#    {'name': 'Putin',
#     'url': 'http://twitter.com/search?q=Putin',
#     'promoted_content': None,
#     'query': 'Putin',
#     'tweet_volume': 158714},
#    {'name': 'Toy Story 5',
#     'url': 'http://twitter.com/search?q=%22Toy+Story+5%22',
#     'promoted_content': None,
#     'query': '%22Toy+Story+5%22',
#     'tweet_volume': 79764},
#    {'name': 'Suns',
#     'url': 'http://twitter.com/search?q=Suns',
#     'promoted_content': None,
#     'query': 'Suns',
#     'tweet_volume': 184998},
#    {'name': 'Death Penalty',
#     'url': 'http://twitter.com/search?q=%22Death+Penalty%22',
#     'promoted_content': None,
#     'query': '%22Death+Penalty%22',
#     'tweet_volume': 20009},
#    {'name': 'Wordle 600 X',
#     'url': 'http://twitter.com/search?q=%22Wordle+600+X%22',
#     'promoted_content': None,
#     'query': '%22Wordle+600+X%22',
#     'tweet_volume': None},
#    {'name': 'Ian Hislop',
#     'url': 'http://twitter.com/search?q=%22Ian+Hislop%22',
#     'promoted_content': None,
#     'query': '%22Ian+Hislop%22',
#     'tweet_volume': None},
#    {'name': 'Verity',
#     'url': 'http://twitter.com/search?q=Verity',
#     'promoted_content': None,
#     'query': 'Verity',
#     'tweet_volume': None},
#    {'name': 'lee rigby',
#     'url': 'http://twitter.com/search?q=%22lee+rigby%22',
#     'promoted_content': None,
#     'query': '%22lee+rigby%22',
#     'tweet_volume': None},
#    {'name': 'Timothy Evans',
#     'url': 'http://twitter.com/search?q=%22Timothy+Evans%22',
#     'promoted_content': None,
#     'query': '%22Timothy+Evans%22',
#     'tweet_volume': None},
#    {'name': 'Nets',
#     'url': 'http://twitter.com/search?q=Nets',
#     'promoted_content': None,
#     'query': 'Nets',
#     'tweet_volume': 128076},
#    {'name': 'booker',
#     'url': 'http://twitter.com/search?q=booker',
#     'promoted_content': None,
#     'query': 'booker',
#     'tweet_volume': 28316},
#    {'name': 'Ashfield',
#     'url': 'http://twitter.com/search?q=Ashfield',
#     'promoted_content': None,
#     'query': 'Ashfield',
#     'tweet_volume': None},
#    {'name': 'West Lancashire',
#     'url': 'http://twitter.com/search?q=%22West+Lancashire%22',
#     'promoted_content': None,
#     'query': '%22West+Lancashire%22',
#     'tweet_volume': None},
#    {'name': 'Mone',
#     'url': 'http://twitter.com/search?q=Mone',
#     'promoted_content': None,
#     'query': 'Mone',
#     'tweet_volume': 19106},
#    {'name': 'Brooklyn',
#     'url': 'http://twitter.com/search?q=Brooklyn',
#     'promoted_content': None,
#     'query': 'Brooklyn',
#     'tweet_volume': 64842},
#    {'name': 'New Tory',
#     'url': 'http://twitter.com/search?q=%22New+Tory%22',
#     'promoted_content': None,
#     'query': '%22New+Tory%22',
#     'tweet_volume': 10601},
#    {'name': 'Ben Simmons',
#     'url': 'http://twitter.com/search?q=%22Ben+Simmons%22',
#     'promoted_content': None,
#     'query': '%22Ben+Simmons%22',
#     'tweet_volume': 21937},
#    {'name': 'Starlink',
#     'url': 'http://twitter.com/search?q=Starlink',
#     'promoted_content': None,
#     'query': 'Starlink',
#     'tweet_volume': 43618},
#    {'name': 'Daily Quordle 381',
#     'url': 'http://twitter.com/search?q=%22Daily+Quordle+381%22',
#     'promoted_content': None,
#     'query': '%22Daily+Quordle+381%22',
#     'tweet_volume': None},
#    {'name': 'Twitter Blue',
#     'url': 'http://twitter.com/search?q=%22Twitter+Blue%22',
#     'promoted_content': None,
#     'query': '%22Twitter+Blue%22',
#     'tweet_volume': 233107},
#    {'name': 'martin lewis',
#     'url': 'http://twitter.com/search?q=%22martin+lewis%22',
#     'promoted_content': None,
#     'query': '%22martin+lewis%22',
#     'tweet_volume': None},
#    {'name': 'Priti Patel',
#     'url': 'http://twitter.com/search?q=%22Priti+Patel%22',
#     'promoted_content': None,
#     'query': '%22Priti+Patel%22',
#     'tweet_volume': None},
#    {'name': 'Mastodon',
#     'url': 'http://twitter.com/search?q=Mastodon',
#     'promoted_content': None,
#     'query': 'Mastodon',
#     'tweet_volume': 14294},
#    {'name': 'Musk',
#     'url': 'http://twitter.com/search?q=Musk',
#     'promoted_content': None,
#     'query': 'Musk',
#     'tweet_volume': 225168},
#    {'name': 'Kate Bush',
#     'url': 'http://twitter.com/search?q=%22Kate+Bush%22',
#     'promoted_content': None,
#     'query': '%22Kate+Bush%22',
#     'tweet_volume': None},
#    {'name': 'Morning Karen',
#     'url': 'http://twitter.com/search?q=%22Morning+Karen%22',
#     'promoted_content': None,
#     'query': '%22Morning+Karen%22',
#     'tweet_volume': None},
#    {'name': 'Breaking Bad',
#     'url': 'http://twitter.com/search?q=%22Breaking+Bad%22',
#     'promoted_content': None,
#     'query': '%22Breaking+Bad%22',
#     'tweet_volume': 11280},
#    {'name': 'Skubala',
#     'url': 'http://twitter.com/search?q=Skubala',
#     'promoted_content': None,
#     'query': 'Skubala',
#     'tweet_volume': None},
#    {'name': 'Metroid Prime',
#     'url': 'http://twitter.com/search?q=%22Metroid+Prime%22',
#     'promoted_content': None,
#     'query': '%22Metroid+Prime%22',
#     'tweet_volume': 47934},
#    {'name': 'Frozen 3',
#     'url': 'http://twitter.com/search?q=%22Frozen+3%22',
#     'promoted_content': None,
#     'query': '%22Frozen+3%22',
#     'tweet_volume': 67103},
#    {'name': 'Levelling',
#     'url': 'http://twitter.com/search?q=Levelling',
#     'promoted_content': None,
#     'query': 'Levelling',
#     'tweet_volume': None},
#    {'name': 'Zootopia 2',
#     'url': 'http://twitter.com/search?q=%22Zootopia+2%22',
#     'promoted_content': None,
#     'query': '%22Zootopia+2%22',
#     'tweet_volume': 66410},
#    {'name': 'Roger Waters',
#     'url': 'http://twitter.com/search?q=%22Roger+Waters%22',
#     'promoted_content': None,
#     'query': '%22Roger+Waters%22',
#     'tweet_volume': 19105},
#    {'name': 'Kanye',
#     'url': 'http://twitter.com/search?q=Kanye',
#     'promoted_content': None,
#     'query': 'Kanye',
#     'tweet_volume': 24400},
#    {'name': 'Professor Layton',
#     'url': 'http://twitter.com/search?q=%22Professor+Layton%22',
#     'promoted_content': None,
#     'query': '%22Professor+Layton%22',
#     'tweet_volume': 33538},
#    {'name': 'Morning Paul',
#     'url': 'http://twitter.com/search?q=%22Morning+Paul%22',
#     'promoted_content': None,
#     'query': '%22Morning+Paul%22',
#     'tweet_volume': None},
#    {'name': 'Deputy Chair',
#     'url': 'http://twitter.com/search?q=%22Deputy+Chair%22',
#     'promoted_content': None,
#     'query': '%22Deputy+Chair%22',
#     'tweet_volume': None},
#    {'name': 'Eminem',
#     'url': 'http://twitter.com/search?q=Eminem',
#     'promoted_content': None,
#     'query': 'Eminem',
#     'tweet_volume': 25106}],
#   'as_of': '2023-02-09T11:30:13Z',
#   'created_at': '2023-02-06T13:38:49Z',
#   'locations': [{'name': 'London', 'woeid': 44418}]}]

# %%
import pandas as pd

# Create a DF
london_trends_pd = pd.DataFrame(london_trends[0]['trends'])

london_trends_pd
# Out:
#                      name                                                url  \
# 0                #NAW2023             http://twitter.com/search?q=%23NAW2023
# 1            #ThisMorning         http://twitter.com/search?q=%23ThisMorning
# 2                  Durant                 http://twitter.com/search?q=Durant
# 3                    Elon                   http://twitter.com/search?q=Elon
# 4          #skillsforlife       http://twitter.com/search?q=%23skillsforlife
# 5        #apprenticeships     http://twitter.com/search?q=%23apprenticeships
# 6                    Russ                   http://twitter.com/search?q=Russ
# 7               Churchill              http://twitter.com/search?q=Churchill
# 8            Lee Anderson     http://twitter.com/search?q=%22Lee+Anderson%22
# 9   European Super League  http://twitter.com/search?q=%22European+Super+...
# 10           Brian Hughes     http://twitter.com/search?q=%22Brian+Hughes%22
# 11                  Putin                  http://twitter.com/search?q=Putin
# 12            Toy Story 5      http://twitter.com/search?q=%22Toy+Story+5%22
# 13                   Suns                   http://twitter.com/search?q=Suns
# 14          Death Penalty    http://twitter.com/search?q=%22Death+Penalty%22
# 15           Wordle 600 X     http://twitter.com/search?q=%22Wordle+600+X%22
# 16             Ian Hislop       http://twitter.com/search?q=%22Ian+Hislop%22
# 17                 Verity                 http://twitter.com/search?q=Verity
# 18              lee rigby        http://twitter.com/search?q=%22lee+rigby%22
# 19          Timothy Evans    http://twitter.com/search?q=%22Timothy+Evans%22
# 20                   Nets                   http://twitter.com/search?q=Nets
# 21                 booker                 http://twitter.com/search?q=booker
# 22               Ashfield               http://twitter.com/search?q=Ashfield
# 23        West Lancashire  http://twitter.com/search?q=%22West+Lancashire%22
# 24                   Mone                   http://twitter.com/search?q=Mone
# 25               Brooklyn               http://twitter.com/search?q=Brooklyn
# 26               New Tory         http://twitter.com/search?q=%22New+Tory%22
# 27            Ben Simmons      http://twitter.com/search?q=%22Ben+Simmons%22
# 28               Starlink               http://twitter.com/search?q=Starlink
# 29      Daily Quordle 381  http://twitter.com/search?q=%22Daily+Quordle+3...
# 30           Twitter Blue     http://twitter.com/search?q=%22Twitter+Blue%22
# 31           martin lewis     http://twitter.com/search?q=%22martin+lewis%22
# 32            Priti Patel      http://twitter.com/search?q=%22Priti+Patel%22
# 33               Mastodon               http://twitter.com/search?q=Mastodon
# 34                   Musk                   http://twitter.com/search?q=Musk
# 35              Kate Bush        http://twitter.com/search?q=%22Kate+Bush%22
# 36          Morning Karen    http://twitter.com/search?q=%22Morning+Karen%22
# 37           Breaking Bad     http://twitter.com/search?q=%22Breaking+Bad%22
# 38                Skubala                http://twitter.com/search?q=Skubala
# 39          Metroid Prime    http://twitter.com/search?q=%22Metroid+Prime%22
# 40               Frozen 3         http://twitter.com/search?q=%22Frozen+3%22
# 41              Levelling              http://twitter.com/search?q=Levelling
# 42             Zootopia 2       http://twitter.com/search?q=%22Zootopia+2%22
# 43           Roger Waters     http://twitter.com/search?q=%22Roger+Waters%22
# 44                  Kanye                  http://twitter.com/search?q=Kanye
# 45       Professor Layton  http://twitter.com/search?q=%22Professor+Layto...
# 46           Morning Paul     http://twitter.com/search?q=%22Morning+Paul%22
# 47           Deputy Chair     http://twitter.com/search?q=%22Deputy+Chair%22
# 48                 Eminem                 http://twitter.com/search?q=Eminem
#
#    promoted_content                        query  tweet_volume
# 0              None                   %23NAW2023           NaN
# 1              None               %23ThisMorning           NaN
# 2              None                       Durant      144569.0
# 3              None                         Elon      351642.0
# 4              None             %23skillsforlife           NaN
# 5              None           %23apprenticeships           NaN
# 6              None                         Russ       66798.0
# 7              None                    Churchill       11997.0
# 8              None           %22Lee+Anderson%22       38344.0
# 9              None  %22European+Super+League%22           NaN
# 10             None           %22Brian+Hughes%22           NaN
# 11             None                        Putin      158714.0
# 12             None            %22Toy+Story+5%22       79764.0
# 13             None                         Suns      184998.0
# 14             None          %22Death+Penalty%22       20009.0
# 15             None           %22Wordle+600+X%22           NaN
# 16             None             %22Ian+Hislop%22           NaN
# 17             None                       Verity           NaN
# 18             None              %22lee+rigby%22           NaN
# 19             None          %22Timothy+Evans%22           NaN
# 20             None                         Nets      128076.0
# 21             None                       booker       28316.0
# 22             None                     Ashfield           NaN
# 23             None        %22West+Lancashire%22           NaN
# 24             None                         Mone       19106.0
# 25             None                     Brooklyn       64842.0
# 26             None               %22New+Tory%22       10601.0
# 27             None            %22Ben+Simmons%22       21937.0
# 28             None                     Starlink       43618.0
# 29             None      %22Daily+Quordle+381%22           NaN
# 30             None           %22Twitter+Blue%22      233107.0
# 31             None           %22martin+lewis%22           NaN
# 32             None            %22Priti+Patel%22           NaN
# 33             None                     Mastodon       14294.0
# 34             None                         Musk      225168.0
# 35             None              %22Kate+Bush%22           NaN
# 36             None          %22Morning+Karen%22           NaN
# 37             None           %22Breaking+Bad%22       11280.0
# 38             None                      Skubala           NaN
# 39             None          %22Metroid+Prime%22       47934.0
# 40             None               %22Frozen+3%22       67103.0
# 41             None                    Levelling           NaN
# 42             None             %22Zootopia+2%22       66410.0
# 43             None           %22Roger+Waters%22       19105.0
# 44             None                        Kanye       24400.0
# 45             None       %22Professor+Layton%22       33538.0
# 46             None           %22Morning+Paul%22           NaN
# 47             None           %22Deputy+Chair%22           NaN
# 48             None                       Eminem       25106.0

# %%
# Limit to 500k tweets - note: 500k return 0, changed to 100k

london_trends_500k_pd = london_trends_pd[london_trends_pd['tweet_volume'] > 100000]\
.sort_values('tweet_volume', ascending=False)

print(london_trends_500k_pd.shape)
london_trends_500k_pd
# Out:
# (7, 5)
#             name                                             url  \
# 3           Elon                http://twitter.com/search?q=Elon
# 30  Twitter Blue  http://twitter.com/search?q=%22Twitter+Blue%22
# 34          Musk                http://twitter.com/search?q=Musk
# 13          Suns                http://twitter.com/search?q=Suns
# 11         Putin               http://twitter.com/search?q=Putin
# 2         Durant              http://twitter.com/search?q=Durant
# 20          Nets                http://twitter.com/search?q=Nets
#
#    promoted_content               query  tweet_volume
# 3              None                Elon      351642.0
# 30             None  %22Twitter+Blue%22      233107.0
# 34             None                Musk      225168.0
# 13             None                Suns      184998.0
# 11             None               Putin      158714.0
# 2              None              Durant      144569.0
# 20             None                Nets      128076.0

# %%
# Save to csv
london_trends_500k_pd.to_csv('london_trends_500k.csv', index=False)

# %% [markdown]
# ## New York

# %%
# Find NY
our_city = 'New York'

# Create a variable.
new_york = [_ for _ in trends_worldwide if _['name'] == our_city]

# View the output.
new_york[0]['woeid']
# Out:
# 2459115

# %%
# Import JSON.
import json

# Search for NY
ny_trends = twitter_api.trends.place(_id=2459115)

# View JSON output.
print (json.dumps(ny_trends, indent=4))
# Out:
# [
#     {
#         "trends": [
#             {
#                 "name": "Russ",
#                 "url": "http://twitter.com/search?q=Russ",
#                 "promoted_content": null,
#                 "query": "Russ",
#                 "tweet_volume": 66832
#             },
#             {
#                 "name": "Suns",
#                 "url": "http://twitter.com/search?q=Suns",
#                 "promoted_content": null,
#                 "query": "Suns",
#                 "tweet_volume": 185628
#             },
#             {
#                 "name": "Nets",
#                 "url": "http://twitter.com/search?q=Nets",
#                 "promoted_content": null,
#                 "query": "Nets",
#                 "tweet_volume": 128486
#             },
#             {
#                 "name": "Ben Simmons",
#                 "url": "http://twitter.com/search?q=%22Ben+Simmons%22",
#                 "promoted_content": null,
#                 "query": "%22Ben+Simmons%22",
#                 "tweet_volume": 22139
#             },
#             {
#                 "name": "Ayton",
#                 "url": "http://twitter.com/search?q=Ayton",
#                 "promoted_content": null,
#                 "query": "Ayton",
#                 "tweet_volume": 25863
#             },
#             {
#                 "name": "Mikal",
#                 "url": "http://twitter.com/search?q=Mikal",
#                 "promoted_content": null,
#                 "query": "Mikal",
#                 "tweet_volume": 58565
#             },
#             {
#                 "name": "Booker",
#                 "url": "http://twitter.com/search?q=Booker",
#                 "promoted_content": null,
#                 "query": "Booker",
#                 "tweet_volume": 28492
#             },
#             {
#                 "name": "Chris Paul",
#                 "url": "http://twitter.com/search?q=%22Chris+Paul%22",
#                 "promoted_content": null,
#                 "query": "%22Chris+Paul%22",
#                 "tweet_volume": 18646
#             },
#             {
#                 "name": "#NBATradeDeadline",
#                 "url": "http://twitter.com/search?q=%23NBATradeDeadline",
#                 "promoted_content": null,
#                 "query": "%23NBATradeDeadline",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "takuto",
#                 "url": "http://twitter.com/search?q=takuto",
#                 "promoted_content": null,
#                 "query": "takuto",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "The NBA",
#                 "url": "http://twitter.com/search?q=%22The+NBA%22",
#                 "promoted_content": null,
#                 "query": "%22The+NBA%22",
#                 "tweet_volume": 195077
#             },
#             {
#                 "name": "Wordle 600 X",
#                 "url": "http://twitter.com/search?q=%22Wordle+600+X%22",
#                 "promoted_content": null,
#                 "query": "%22Wordle+600+X%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Cam Johnson",
#                 "url": "http://twitter.com/search?q=%22Cam+Johnson%22",
#                 "promoted_content": null,
#                 "query": "%22Cam+Johnson%22",
#                 "tweet_volume": 32642
#             },
#             {
#                 "name": "KD and Kyrie",
#                 "url": "http://twitter.com/search?q=%22KD+and+Kyrie%22",
#                 "promoted_content": null,
#                 "query": "%22KD+and+Kyrie%22",
#                 "tweet_volume": 13518
#             },
#             {
#                 "name": "Joe Tsai",
#                 "url": "http://twitter.com/search?q=%22Joe+Tsai%22",
#                 "promoted_content": null,
#                 "query": "%22Joe+Tsai%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "The West",
#                 "url": "http://twitter.com/search?q=%22The+West%22",
#                 "promoted_content": null,
#                 "query": "%22The+West%22",
#                 "tweet_volume": 144314
#             },
#             {
#                 "name": "Good Thursday",
#                 "url": "http://twitter.com/search?q=%22Good+Thursday%22",
#                 "promoted_content": null,
#                 "query": "%22Good+Thursday%22",
#                 "tweet_volume": 14472
#             },
#             {
#                 "name": "TJ Warren",
#                 "url": "http://twitter.com/search?q=%22TJ+Warren%22",
#                 "promoted_content": null,
#                 "query": "%22TJ+Warren%22",
#                 "tweet_volume": 20096
#             },
#             {
#                 "name": "#NationalPizzaDay",
#                 "url": "http://twitter.com/search?q=%23NationalPizzaDay",
#                 "promoted_content": null,
#                 "query": "%23NationalPizzaDay",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "KD to Phoenix",
#                 "url": "http://twitter.com/search?q=%22KD+to+Phoenix%22",
#                 "promoted_content": null,
#                 "query": "%22KD+to+Phoenix%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Jae Crowder",
#                 "url": "http://twitter.com/search?q=%22Jae+Crowder%22",
#                 "promoted_content": null,
#                 "query": "%22Jae+Crowder%22",
#                 "tweet_volume": 25318
#             },
#             {
#                 "name": "#YouNetflix",
#                 "url": "http://twitter.com/search?q=%23YouNetflix",
#                 "promoted_content": null,
#                 "query": "%23YouNetflix",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "James O'Keefe",
#                 "url": "http://twitter.com/search?q=%22James+O%27Keefe%22",
#                 "promoted_content": null,
#                 "query": "%22James+O%27Keefe%22",
#                 "tweet_volume": 48113
#             },
#             {
#                 "name": "Kyrie and KD",
#                 "url": "http://twitter.com/search?q=%22Kyrie+and+KD%22",
#                 "promoted_content": null,
#                 "query": "%22Kyrie+and+KD%22",
#                 "tweet_volume": 13563
#             },
#             {
#                 "name": "Daily Quordle 381",
#                 "url": "http://twitter.com/search?q=%22Daily+Quordle+381%22",
#                 "promoted_content": null,
#                 "query": "%22Daily+Quordle+381%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Clippers",
#                 "url": "http://twitter.com/search?q=Clippers",
#                 "promoted_content": null,
#                 "query": "Clippers",
#                 "tweet_volume": 30217
#             },
#             {
#                 "name": "Sean Marks",
#                 "url": "http://twitter.com/search?q=%22Sean+Marks%22",
#                 "promoted_content": null,
#                 "query": "%22Sean+Marks%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "KD is a Sun",
#                 "url": "http://twitter.com/search?q=%22KD+is+a+Sun%22",
#                 "promoted_content": null,
#                 "query": "%22KD+is+a+Sun%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "DBook",
#                 "url": "http://twitter.com/search?q=DBook",
#                 "promoted_content": null,
#                 "query": "DBook",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "David Stern",
#                 "url": "http://twitter.com/search?q=%22David+Stern%22",
#                 "promoted_content": null,
#                 "query": "%22David+Stern%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#WeAreTheValley",
#                 "url": "http://twitter.com/search?q=%23WeAreTheValley",
#                 "promoted_content": null,
#                 "query": "%23WeAreTheValley",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "claxton",
#                 "url": "http://twitter.com/search?q=claxton",
#                 "promoted_content": null,
#                 "query": "claxton",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Josh Hart",
#                 "url": "http://twitter.com/search?q=%22Josh+Hart%22",
#                 "promoted_content": null,
#                 "query": "%22Josh+Hart%22",
#                 "tweet_volume": 29049
#             },
#             {
#                 "name": "KD to PHX",
#                 "url": "http://twitter.com/search?q=%22KD+to+PHX%22",
#                 "promoted_content": null,
#                 "query": "%22KD+to+PHX%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Vernon",
#                 "url": "http://twitter.com/search?q=Vernon",
#                 "promoted_content": null,
#                 "query": "Vernon",
#                 "tweet_volume": 37302
#             },
#             {
#                 "name": "Damn KD",
#                 "url": "http://twitter.com/search?q=%22Damn+KD%22",
#                 "promoted_content": null,
#                 "query": "%22Damn+KD%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Toy Story 5",
#                 "url": "http://twitter.com/search?q=%22Toy+Story+5%22",
#                 "promoted_content": null,
#                 "query": "%22Toy+Story+5%22",
#                 "tweet_volume": 80092
#             },
#             {
#                 "name": "Blazers",
#                 "url": "http://twitter.com/search?q=Blazers",
#                 "promoted_content": null,
#                 "query": "Blazers",
#                 "tweet_volume": 25062
#             },
#             {
#                 "name": "#MetroidPrimeRemastered",
#                 "url": "http://twitter.com/search?q=%23MetroidPrimeRemastered",
#                 "promoted_content": null,
#                 "query": "%23MetroidPrimeRemastered",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Seth Curry",
#                 "url": "http://twitter.com/search?q=%22Seth+Curry%22",
#                 "promoted_content": null,
#                 "query": "%22Seth+Curry%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "seob",
#                 "url": "http://twitter.com/search?q=seob",
#                 "promoted_content": null,
#                 "query": "seob",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "kd & kyrie",
#                 "url": "http://twitter.com/search?q=%22kd+%26+kyrie%22",
#                 "promoted_content": null,
#                 "query": "%22kd+%26+kyrie%22",
#                 "tweet_volume": 23359
#             },
#             {
#                 "name": "Tupac",
#                 "url": "http://twitter.com/search?q=Tupac",
#                 "promoted_content": null,
#                 "query": "Tupac",
#                 "tweet_volume": 11455
#             },
#             {
#                 "name": "Sixers",
#                 "url": "http://twitter.com/search?q=Sixers",
#                 "promoted_content": null,
#                 "query": "Sixers",
#                 "tweet_volume": 16405
#             },
#             {
#                 "name": "Illey",
#                 "url": "http://twitter.com/search?q=Illey",
#                 "promoted_content": null,
#                 "query": "Illey",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Torrey Craig",
#                 "url": "http://twitter.com/search?q=%22Torrey+Craig%22",
#                 "promoted_content": null,
#                 "query": "%22Torrey+Craig%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Fetterman",
#                 "url": "http://twitter.com/search?q=Fetterman",
#                 "promoted_content": null,
#                 "query": "Fetterman",
#                 "tweet_volume": 17030
#             },
#             {
#                 "name": "Rockets",
#                 "url": "http://twitter.com/search?q=Rockets",
#                 "promoted_content": null,
#                 "query": "Rockets",
#                 "tweet_volume": 17580
#             },
#             {
#                 "name": "Zootopia 2",
#                 "url": "http://twitter.com/search?q=%22Zootopia+2%22",
#                 "promoted_content": null,
#                 "query": "%22Zootopia+2%22",
#                 "tweet_volume": 66675
#             },
#             {
#                 "name": "James Jones",
#                 "url": "http://twitter.com/search?q=%22James+Jones%22",
#                 "promoted_content": null,
#                 "query": "%22James+Jones%22",
#                 "tweet_volume": null
#             }
#         ],
#         "as_of": "2023-02-09T11:33:57Z",
#         "created_at": "2023-02-08T14:19:22Z",
#         "locations": [
#             {
#                 "name": "New York",
#                 "woeid": 2459115
#             }
#         ]
#     }
# ]

# %%
# Create a DF
ny_trends_pd = pd.DataFrame(ny_trends[0]['trends'])

ny_trends_pd
# Out:
#                        name  \
# 0                      Russ
# 1                      Suns
# 2                      Nets
# 3               Ben Simmons
# 4                     Ayton
# 5                     Mikal
# 6                    Booker
# 7                Chris Paul
# 8         #NBATradeDeadline
# 9                    takuto
# 10                  The NBA
# 11             Wordle 600 X
# 12              Cam Johnson
# 13             KD and Kyrie
# 14                 Joe Tsai
# 15                 The West
# 16            Good Thursday
# 17                TJ Warren
# 18        #NationalPizzaDay
# 19            KD to Phoenix
# 20              Jae Crowder
# 21              #YouNetflix
# 22            James O'Keefe
# 23             Kyrie and KD
# 24        Daily Quordle 381
# 25                 Clippers
# 26               Sean Marks
# 27              KD is a Sun
# 28                    DBook
# 29              David Stern
# 30          #WeAreTheValley
# 31                  claxton
# 32                Josh Hart
# 33                KD to PHX
# 34                   Vernon
# 35                  Damn KD
# 36              Toy Story 5
# 37                  Blazers
# 38  #MetroidPrimeRemastered
# 39               Seth Curry
# 40                     seob
# 41               kd & kyrie
# 42                    Tupac
# 43                   Sixers
# 44                    Illey
# 45             Torrey Craig
# 46                Fetterman
# 47                  Rockets
# 48               Zootopia 2
# 49              James Jones
#
#                                                   url promoted_content  \
# 0                    http://twitter.com/search?q=Russ             None
# 1                    http://twitter.com/search?q=Suns             None
# 2                    http://twitter.com/search?q=Nets             None
# 3       http://twitter.com/search?q=%22Ben+Simmons%22             None
# 4                   http://twitter.com/search?q=Ayton             None
# 5                   http://twitter.com/search?q=Mikal             None
# 6                  http://twitter.com/search?q=Booker             None
# 7        http://twitter.com/search?q=%22Chris+Paul%22             None
# 8     http://twitter.com/search?q=%23NBATradeDeadline             None
# 9                  http://twitter.com/search?q=takuto             None
# 10          http://twitter.com/search?q=%22The+NBA%22             None
# 11     http://twitter.com/search?q=%22Wordle+600+X%22             None
# 12      http://twitter.com/search?q=%22Cam+Johnson%22             None
# 13     http://twitter.com/search?q=%22KD+and+Kyrie%22             None
# 14         http://twitter.com/search?q=%22Joe+Tsai%22             None
# 15         http://twitter.com/search?q=%22The+West%22             None
# 16    http://twitter.com/search?q=%22Good+Thursday%22             None
# 17        http://twitter.com/search?q=%22TJ+Warren%22             None
# 18    http://twitter.com/search?q=%23NationalPizzaDay             None
# 19    http://twitter.com/search?q=%22KD+to+Phoenix%22             None
# 20      http://twitter.com/search?q=%22Jae+Crowder%22             None
# 21          http://twitter.com/search?q=%23YouNetflix             None
# 22  http://twitter.com/search?q=%22James+O%27Keefe%22             None
# 23     http://twitter.com/search?q=%22Kyrie+and+KD%22             None
# 24  http://twitter.com/search?q=%22Daily+Quordle+3...             None
# 25               http://twitter.com/search?q=Clippers             None
# 26       http://twitter.com/search?q=%22Sean+Marks%22             None
# 27      http://twitter.com/search?q=%22KD+is+a+Sun%22             None
# 28                  http://twitter.com/search?q=DBook             None
# 29      http://twitter.com/search?q=%22David+Stern%22             None
# 30      http://twitter.com/search?q=%23WeAreTheValley             None
# 31                http://twitter.com/search?q=claxton             None
# 32        http://twitter.com/search?q=%22Josh+Hart%22             None
# 33        http://twitter.com/search?q=%22KD+to+PHX%22             None
# 34                 http://twitter.com/search?q=Vernon             None
# 35          http://twitter.com/search?q=%22Damn+KD%22             None
# 36      http://twitter.com/search?q=%22Toy+Story+5%22             None
# 37                http://twitter.com/search?q=Blazers             None
# 38  http://twitter.com/search?q=%23MetroidPrimeRem...             None
# 39       http://twitter.com/search?q=%22Seth+Curry%22             None
# 40                   http://twitter.com/search?q=seob             None
# 41     http://twitter.com/search?q=%22kd+%26+kyrie%22             None
# 42                  http://twitter.com/search?q=Tupac             None
# 43                 http://twitter.com/search?q=Sixers             None
# 44                  http://twitter.com/search?q=Illey             None
# 45     http://twitter.com/search?q=%22Torrey+Craig%22             None
# 46              http://twitter.com/search?q=Fetterman             None
# 47                http://twitter.com/search?q=Rockets             None
# 48       http://twitter.com/search?q=%22Zootopia+2%22             None
# 49      http://twitter.com/search?q=%22James+Jones%22             None
#
#                         query  tweet_volume
# 0                        Russ       66832.0
# 1                        Suns      185628.0
# 2                        Nets      128486.0
# 3           %22Ben+Simmons%22       22139.0
# 4                       Ayton       25863.0
# 5                       Mikal       58565.0
# 6                      Booker       28492.0
# 7            %22Chris+Paul%22       18646.0
# 8         %23NBATradeDeadline           NaN
# 9                      takuto           NaN
# 10              %22The+NBA%22      195077.0
# 11         %22Wordle+600+X%22           NaN
# 12          %22Cam+Johnson%22       32642.0
# 13         %22KD+and+Kyrie%22       13518.0
# 14             %22Joe+Tsai%22           NaN
# 15             %22The+West%22      144314.0
# 16        %22Good+Thursday%22       14472.0
# 17            %22TJ+Warren%22       20096.0
# 18        %23NationalPizzaDay           NaN
# 19        %22KD+to+Phoenix%22           NaN
# 20          %22Jae+Crowder%22       25318.0
# 21              %23YouNetflix           NaN
# 22      %22James+O%27Keefe%22       48113.0
# 23         %22Kyrie+and+KD%22       13563.0
# 24    %22Daily+Quordle+381%22           NaN
# 25                   Clippers       30217.0
# 26           %22Sean+Marks%22           NaN
# 27          %22KD+is+a+Sun%22           NaN
# 28                      DBook           NaN
# 29          %22David+Stern%22           NaN
# 30          %23WeAreTheValley           NaN
# 31                    claxton           NaN
# 32            %22Josh+Hart%22       29049.0
# 33            %22KD+to+PHX%22           NaN
# 34                     Vernon       37302.0
# 35              %22Damn+KD%22           NaN
# 36          %22Toy+Story+5%22       80092.0
# 37                    Blazers       25062.0
# 38  %23MetroidPrimeRemastered           NaN
# 39           %22Seth+Curry%22           NaN
# 40                       seob           NaN
# 41         %22kd+%26+kyrie%22       23359.0
# 42                      Tupac       11455.0
# 43                     Sixers       16405.0
# 44                      Illey           NaN
# 45         %22Torrey+Craig%22           NaN
# 46                  Fetterman       17030.0
# 47                    Rockets       17580.0
# 48           %22Zootopia+2%22       66675.0
# 49          %22James+Jones%22           NaN

# %%
# Narrow the list down to 500,000 tweets.

ny_trends_over500k_pd = ny_trends_pd[ny_trends_pd['tweet_volume'] > 100000]\
.sort_values('tweet_volume', ascending=False)

# View the output.
print(ny_trends_over500k_pd.shape)
ny_trends_over500k_pd
# Out:
# (4, 5)
#         name                                         url promoted_content  \
# 10   The NBA   http://twitter.com/search?q=%22The+NBA%22             None
# 1       Suns            http://twitter.com/search?q=Suns             None
# 15  The West  http://twitter.com/search?q=%22The+West%22             None
# 2       Nets            http://twitter.com/search?q=Nets             None
#
#              query  tweet_volume
# 10   %22The+NBA%22      195077.0
# 1             Suns      185628.0
# 15  %22The+West%22      144314.0
# 2             Nets      128486.0

# %%
# Save output as CSV file.
ny_trends_over500k_pd.to_csv('ct_over500k.csv', index=False)

# %% [markdown]
# ## 3. Common trends

# %%
# Find common topics.
london_trends_list = [trend['name'] for trend in london_trends[0]['trends']]

# View the output.
print(london_trends_list)
# Out:
# ['#NAW2023', '#ThisMorning', 'Durant', 'Elon', '#skillsforlife', '#apprenticeships', 'Russ', 'Churchill', 'Lee Anderson', 'European Super League', 'Brian Hughes', 'Putin', 'Toy Story 5', 'Suns', 'Death Penalty', 'Wordle 600 X', 'Ian Hislop', 'Verity', 'lee rigby', 'Timothy Evans', 'Nets', 'booker', 'Ashfield', 'West Lancashire', 'Mone', 'Brooklyn', 'New Tory', 'Ben Simmons', 'Starlink', 'Daily Quordle 381', 'Twitter Blue', 'martin lewis', 'Priti Patel', 'Mastodon', 'Musk', 'Kate Bush', 'Morning Karen', 'Breaking Bad', 'Skubala', 'Metroid Prime', 'Frozen 3', 'Levelling', 'Zootopia 2', 'Roger Waters', 'Kanye', 'Professor Layton', 'Morning Paul', 'Deputy Chair', 'Eminem']

# %%
# Find common topic(s).
ny_trends_list =[trend['name'] for trend in ny_trends[0]['trends']]

# View the output.
print(ny_trends_list)
# Out:
# ['Russ', 'Suns', 'Nets', 'Ben Simmons', 'Ayton', 'Mikal', 'Booker', 'Chris Paul', '#NBATradeDeadline', 'takuto', 'The NBA', 'Wordle 600 X', 'Cam Johnson', 'KD and Kyrie', 'Joe Tsai', 'The West', 'Good Thursday', 'TJ Warren', '#NationalPizzaDay', 'KD to Phoenix', 'Jae Crowder', '#YouNetflix', "James O'Keefe", 'Kyrie and KD', 'Daily Quordle 381', 'Clippers', 'Sean Marks', 'KD is a Sun', 'DBook', 'David Stern', '#WeAreTheValley', 'claxton', 'Josh Hart', 'KD to PHX', 'Vernon', 'Damn KD', 'Toy Story 5', 'Blazers', '#MetroidPrimeRemastered', 'Seth Curry', 'seob', 'kd & kyrie', 'Tupac', 'Sixers', 'Illey', 'Torrey Craig', 'Fetterman', 'Rockets', 'Zootopia 2', 'James Jones']

# %%
# Find common trends between cities.
london_trends_set = set(london_trends_list)
ny_trends_set = set(ny_trends_list)

# Set the variable.
common_trends = london_trends_set.intersection(ny_trends_set)

# View the output.
print(common_trends)
# Out:
# {'Nets', 'Toy Story 5', 'Daily Quordle 381', 'Russ', 'Zootopia 2', 'Wordle 600 X', 'Suns', 'Ben Simmons'}

# %% [markdown]
# ## Search for Bitcoin

# %%
# Search for Bitcoin

q = '#Bitcoin'

# Set count to 100.
Count = 100

# %%
# Read some tweets.
search_results = twitter_api.search.tweets(q=q, count=100)

statuses = search_results['statuses']

# %%
for _ in range(5):
    print("Length of statuses", len(statuses))
    try:
        next_results = search_results['search_metadata']['next_results']
    except KeyError: # No more results when next_results doesn't exist
        break
        
    # Create a dictionary from next_results
    kwargs = dict([ kv.split('=') for kv in next_results[1:].split("&") ])
    
    search_results = twitter_api.search.tweets(**kwargs)
    statuses += search_results['statuses']

print(json.dumps(statuses[1], indent=1))
# Out:
# Length of statuses 90
# Length of statuses 158
# Length of statuses 158
# {
#  "created_at": "Thu Feb 09 11:38:24 +0000 2023",
#  "id": 1623647500321140736,
#  "id_str": "1623647500321140736",
#  "text": "If you are new to #bitcoin and you see anyone with .btc or .eth in their name, or if they are trying to say good th\u2026 https://t.co/oBnbx88vuN",
#  "truncated": true,
#  "entities": {
#   "hashtags": [
#    {
#     "text": "bitcoin",
#     "indices": [
#      18,
#      26
#     ]
#    }
#   ],
#   "symbols": [],
#   "user_mentions": [],
#   "urls": [
#    {
#     "url": "https://t.co/oBnbx88vuN",
#     "expanded_url": "https://twitter.com/i/web/status/1623647500321140736",
#     "display_url": "twitter.com/i/web/status/1\u2026",
#     "indices": [
#      117,
#      140
#     ]
#    }
#   ]
#  },
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  },
#  "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#  "in_reply_to_status_id": null,
#  "in_reply_to_status_id_str": null,
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "user": {
#   "id": 1597052366238453760,
#   "id_str": "1597052366238453760",
#   "name": "Ghost Node",
#   "screen_name": "_ghost_node_",
#   "location": "Earth, Sol, Milky Way",
#   "description": "#opensource #openprotocol #selfhosted #privacybydefault #linux #p2p #decentralized #bitcoin #notcrypto #gpg #rumble #vpn #dns GPG is the real PGP.",
#   "url": null,
#   "entities": {
#    "description": {
#     "urls": []
#    }
#   },
#   "protected": false,
#   "followers_count": 42,
#   "friends_count": 1155,
#   "listed_count": 0,
#   "created_at": "Mon Nov 28 02:20:01 +0000 2022",
#   "favourites_count": 1671,
#   "utc_offset": null,
#   "time_zone": null,
#   "geo_enabled": false,
#   "verified": false,
#   "statuses_count": 8,
#   "lang": null,
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "F5F8FA",
#   "profile_background_image_url": null,
#   "profile_background_image_url_https": null,
#   "profile_background_tile": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/1619451119733702658/YWs2meDu_normal.jpg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/1619451119733702658/YWs2meDu_normal.jpg",
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/1597052366238453760/1674942221",
#   "profile_link_color": "1DA1F2",
#   "profile_sidebar_border_color": "C0DEED",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "profile_text_color": "333333",
#   "profile_use_background_image": true,
#   "has_extended_profile": true,
#   "default_profile": true,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none",
#   "withheld_in_countries": []
#  },
#  "geo": null,
#  "coordinates": null,
#  "place": null,
#  "contributors": null,
#  "is_quote_status": false,
#  "retweet_count": 0,
#  "favorite_count": 0,
#  "favorited": false,
#  "retweeted": false,
#  "lang": "en"
# }

# %%
# Check statuses.
t = statuses[0]

# Print the keys.
t.keys()
# Out:
# dict_keys(['created_at', 'id', 'id_str', 'text', 'truncated', 'entities', 'metadata', 'source', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'is_quote_status', 'retweet_count', 'favorite_count', 'favorited', 'retweeted', 'possibly_sensitive', 'lang'])

# %%
# Find the id.
print(t['id'])

# View the ouput in text.
print(t['text'])

# View entities.
t['entities']
# Out:
# 1623647501797531649
# Retweet,if you want @binance to accept #BabyDoge #BabyDogeArmy #Binance #BUSD #BNB #Bitcoin #LUNC #ETH #CZBinance… https://t.co/xz59rZHQIq
# {'hashtags': [{'text': 'BabyDoge', 'indices': [39, 48]},
#   {'text': 'BabyDogeArmy', 'indices': [49, 62]},
#   {'text': 'Binance', 'indices': [63, 71]},
#   {'text': 'BUSD', 'indices': [72, 77]},
#   {'text': 'BNB', 'indices': [78, 82]},
#   {'text': 'Bitcoin', 'indices': [83, 91]},
#   {'text': 'LUNC', 'indices': [92, 97]},
#   {'text': 'ETH', 'indices': [98, 102]},
#   {'text': 'CZBinance', 'indices': [103, 113]}],
#  'symbols': [],
#  'user_mentions': [{'screen_name': 'binance',
#    'name': 'Binance',
#    'id': 877807935493033984,
#    'id_str': '877807935493033984',
#    'indices': [20, 28]}],
#  'urls': [{'url': 'https://t.co/xz59rZHQIq',
#    'expanded_url': 'https://twitter.com/i/web/status/1623647501797531649',
#    'display_url': 'twitter.com/i/web/status/1…',
#    'indices': [115, 138]}]}
